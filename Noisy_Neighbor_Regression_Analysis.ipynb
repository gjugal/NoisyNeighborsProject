# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# %%
vms_df = pd.read_csv("C:/Users/gujju/Desktop/CapstoneWork/4benchmarks/hanoi_480.csv")
print(vms_df)
# Out:
#       vmIpAddr    output                                   cpuType    cpuMhz  \
# 0   10.0.1.112  213669.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1795.672
# 1   10.0.1.116  214011.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1799.999
# 2   10.0.1.122  215052.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1799.999
# 3   10.0.1.127  212554.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1795.673
# 4   10.0.1.128  213664.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1795.672
# 5   10.0.1.134  215722.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1799.999
# 6   10.0.1.136  214863.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1799.999
# 7   10.0.1.137  212859.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1799.999
# 8   10.0.1.145  212665.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1800.000
# 9   10.0.1.147  214297.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1795.672
# 10  10.0.1.160  214723.0  Intel(R) Xeon(R) CPU E5-2650 0 @ 2.00GHz  1795.672
# ...

# %%
output_target = vms_df['output']

# %%
print(vms_df.corr().ix['output', 1:-1])
# Out:
# cpuMhz         0.164366
# sampleTime    -0.365274
# elapsedTime   -0.305938
# cputime        0.239982
# dsr                 NaN
# dsw           -0.306392
# nbr            0.281051
# nbs            0.242822
# cpuusr         0.354999
# cpukrn        -0.324842
# cpuidle       -0.225220
# cpuIoWait     -0.237955
# cIntSrvc            NaN
# cSftIntSrvc   -0.165954
# cCtxtSw       -0.337463
# cpuNice             NaN
# cpuSteal      -0.164309
# dskRds              NaN
# dskMrgdRds          NaN
# dskReadTm           NaN
# dskWrts       -0.196419
# dskMrgdWrts   -0.259557
# dskWrtTm      -0.136122
# ldAvg         -0.209641
# Name: output, dtype: float64
